# %%
# Import modul cv2
import cv2

# Import modul os
import os

# Import modul numpy dan aliasing sebagai np
import numpy as np

from tqdm import tqdm

labels = ['rock', 'paper', 'scissors']

X_train = []
y_train = []
image_size = 128
for i in labels:
    folderPath = os.path.join('rps',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
#   0%|          | 0/840 [00:00<?, ?it/s]
# 100%|██████████| 840/840 [00:01<00:00, 556.64it/s]
# 100%|██████████| 840/840 [00:01<00:00, 529.75it/s]
# 100%|██████████| 840/840 [00:01<00:00, 532.35it/s]

# %%
from sklearn.utils import shuffle

X_train, y_train = shuffle(X_train,y_train, random_state=101)

# %%
X_train.shape
# Out:
# (2520, 128, 128, 3)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %%
import tensorflow as tf

y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)

y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)
# Out:
# WARNING:tensorflow:From c:\Users\MATRIX COMPUTER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=30,  # Rotate the image by a random angle (between -20 and 20 degrees)
    width_shift_range=0.01,  # Shift the image horizontally by a fraction of total width
    height_shift_range=0.01,  # Shift the image vertically by a fraction of total height
    zoom_range=0.2,  # Zoom in or out on the image by a random factor
    horizontal_flip=True,  # Flip the image horizontally
    validation_split=0.111,
)

# %%
train_data = datagen.flow(
    X_train, y_train,
    subset='training',
    )

# %%
val_data = datagen.flow(
    X_train, y_train,
    subset='validation',
    )

# %%
base_model = tf.keras.applications.EfficientNetB0(weights='imagenet',include_top=False,input_shape=(image_size,image_size,3), classes=3)
# Out:
# WARNING:tensorflow:From c:\Users\MATRIX COMPUTER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\MATRIX COMPUTER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization, Dropout, Flatten, Dense, Activation, GlobalAveragePooling2D

model=Sequential()
model.add(base_model)
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.5))
model.add(Dense(1024))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dense(3,activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 4, 4, 1280)        4049571
#  )
#
#  global_average_pooling2d (  (None, 1280)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 1024)              1311744
#
#  activation (Activation)     (None, 1024)              0
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 128)               131200
#
#  activation_1 (Activation)   (None, 128)               0
#
#  dense_2 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 5492902 (20.95 MB)
# Trainable params: 5450879 (20.79 MB)
# Non-trainable params: 42023 (164.16 KB)
# _________________________________________________________________

# %%
# optimizer = tf.keras.optimizers.legacy.Adam()

model.compile(loss='categorical_crossentropy',optimizer = 'Adamax', metrics= ['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\MATRIX COMPUTER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(
        train_data,
        validation_data=val_data,
        epochs =10,
        batch_size=256,
        verbose=1)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\MATRIX COMPUTER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\MATRIX COMPUTER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 64/64 [==============================] - 100s 1s/step - loss: 0.1789 - accuracy: 0.9331 - val_loss: 0.0191 - val_accuracy: 0.9920
# Epoch 2/10
# 64/64 [==============================] - 92s 1s/step - loss: 0.0161 - accuracy: 0.9950 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 3/10
# 64/64 [==============================] - 81s 1s/step - loss: 0.0153 - accuracy: 0.9931 - val_loss: 5.4984e-04 - val_accuracy: 1.0000
# Epoch 4/10
# 64/64 [==============================] - 78s 1s/step - loss: 0.0161 - accuracy: 0.9950 - val_loss: 0.0203 - val_accuracy: 0.9960
# Epoch 5/10
# 64/64 [==============================] - 77s 1s/step - loss: 0.0090 - accuracy: 0.9980 - val_loss: 5.2699e-04 - val_accuracy: 1.0000
# Epoch 6/10
# 64/64 [==============================] - 77s 1s/step - loss: 0.0089 - accuracy: 0.9980 - val_loss: 4.2629e-05 - val_accuracy: 1.0000
# Epoch 7/10
# 64/64 [==============================] - 80s 1s/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 1.3341e-04 - val_accuracy: 1.0000
# Epoch 8/10
# 64/64 [==============================] - 78s 1s/step - loss: 0.0038 - accuracy: 0.9995 - val_loss: 9.6116e-06 - val_accuracy: 1.0000
# Epoch 9/10
# 64/64 [==============================] - 77s 1s/step - loss: 0.0085 - accuracy: 0.9980 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 10/10
# 64/64 [==============================] - 76s 1s/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 2.1126e-04 - val_accuracy: 1.0000

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 8/8 [==============================] - 4s 290ms/step

# %%
model.evaluate(X_test, y_test)
# Out:
# 8/8 [==============================] - 4s 294ms/step - loss: 2.3843e-04 - accuracy: 1.0000
# [0.00023843471717555076, 1.0]

# %%
from sklearn.metrics import classification_report,confusion_matrix

print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        87
#            1       1.00      1.00      1.00        84
#            2       1.00      1.00      1.00        81
#
#     accuracy                           1.00       252
#    macro avg       1.00      1.00      1.00       252
# weighted avg       1.00      1.00      1.00       252

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(10)

plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
prediction = model.predict(X_test)
# Out:
# 8/8 [==============================] - 2s 278ms/step

# %%
import random

class_names = ['rock', 'paper', 'scissors']

random_indices = np.random.choice(len(X_test), 5, replace=False)

for i in random_indices:
    image = X_test[i].astype('uint8')
    predictions = model.predict(np.expand_dims(X_test[i], axis=0))
    predicted_label = class_names[np.argmax(predictions)]
    actual_label = class_names[np.argmax(y_test[i])]
    confidence = round( (np.max(predictions[0])), 2)
    
    plt.imshow(image)
    print("Actual label:", actual_label)
    print("Predicted label:", predicted_label)
    print("Confidence:", {confidence *100})
    plt.show()
# Out:
# 1/1 [==============================] - 0s 56ms/step
# Actual label: rock
# Predicted label: rock
# Confidence: {100.0}
# 1/1 [==============================] - 0s 53ms/step
# Actual label: rock
# Predicted label: rock
# Confidence: {100.0}
# 1/1 [==============================] - 0s 61ms/step
# Actual label: paper
# Predicted label: paper
# Confidence: {100.0}
# 1/1 [==============================] - 0s 49ms/step
# Actual label: scissors
# Predicted label: scissors
# Confidence: {100.0}
# 1/1 [==============================] - 0s 49ms/step
# Actual label: scissors
# Predicted label: scissors
# Confidence: {100.0}

# %%
model.save('mod5.h5')
